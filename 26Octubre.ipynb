# %% [markdown]
# <a href="https://colab.research.google.com/github/Jericohm/daa_2021_1/blob/master/26Octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import time
def ejemplo2( n ):
    contador = 0
    start_time = time()
    for i in range( n ) :
        for j in range( n ) :
            contador += 1
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return contador

def ejemplo3( n ):  
  start_time = time()
  x = n * 2
  y = 0
  for m in range (100):
    y = x - n
  elapsed_time = time() - start_time
  print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
  return y

def ejemplo4( n ):
    start_time = time()
    x = 3 * 3.1416 + n
    y = x + 3 * 3 - n
    z = x + y
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return z

def ejemplo5( x ):
    start_time = time()    
    n = 10
    for j in range( 0 , x , 1 ):
        n = j + n
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return n

def ejemplo6( n ):
    start_time = time()
    data=[[[1 for x in range(n)] for x in range(n)]
          for x in range(n)]
    suma = 0
    for d in range(n):
        for r in range(n):
            for c in range(n):
                suma += data[d][r][c]
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return suma    

def ejemplo7( n ):
    start_time = time()
    count = 0
    for i in range( n ) :
        for j in range( 25 ) :
            for k in range( n ):
                count += 1
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return count

def ejemplo7_2( n ):
    start_time = time()
    count = 0
    for i in range( n ) :
        for j in range( 25 ) :
            for k in range( n ):
                count += 1
            for k in range( n ):
                count += 1
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)          
    return count # 1 + 25n^2 +25n^2

def ejemplo8( numeros ): # numeros es una lista (arreglo en c)
    start_time = time()
    total = 0
    for index in range(len(numeros)):
        total = numeros[index]
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return total # 1 + n

def ejemplo9( n ):
    start_time = time()
    contador = 0
    basura = 0
    for i in range( n ) :
        contador += 1
    for j in range( n ) :
        contador += 1
    basura = basura + contador
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return contador # 3 + 2n

def ejemplo10( n ):
    start_time = time()
    count = 0
    for i in range( n ) :
        for j in range( i+1 ) :
            count += 1
    elapsed_time = time() - start_time
    print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
    return count # 1 + (n^2 + n)/2
    #1 + (n^2 - n)/2 Si se elimina el 1 de i+1    

def ejemplo11( n ):
  count = 0
  i = n
  while i > 1:
    count += 1
    i = i // 2
  return count # 2+2log2(n)

def ejemplo12 ( n ):
  start_time = time()
  contador = 0
  for x in range(n):
    contador += ejemplo11(x)
  elapsed_time = time() - start_time
  print("Tiempo transcurrido: %0.10f segundos." % elapsed_time)
  return contador #1+n(2+2log2(n))

def ejemplo13 ( n ):
  bandera = n
  contador = 0
  while(bandera >= 10):
    print(f"n = {bandera}")
    bandera /= 10
    contador = contador + 1  
  return contador # 1 + log 10 (n)

def ejemplo14 ( n ):
  y = n
  z = n
  contador = 0
  while y >= 3:
    y /= 3
    contador +=1
  while z >= 3:
    z /= 3
    contador += 1
  return contador

def ejemplo15( n ): 
    contador = 0
    for i in range( n ) :
        for j in range( n ) :
            contador += 1
            
    while n > 1 :
        contador += 1
        n /= 2
    return contador

def main():
  vuelta = 1
  h = 27
  #for h in range(100,1100,100):
  #print(vuelta)
  print("Ejemplo 2: ",ejemplo2(h))
  print("Ejemplo 3: ",ejemplo3(h))
  print("Ejemplo 4: ",ejemplo4(h))
  print("Ejemplo 5: ",ejemplo5(h))
  print("Ejemplo 6: ",ejemplo6(h))
  print("Ejemplo 7: ",ejemplo7(h))
  print("Ejemplo 7_2: ",ejemplo7_2(h))
  print("Ejemplo 8: ",ejemplo8([1,2,3,4,5,6]))
  print("Ejemplo 9: ",ejemplo9(h))
  print("Ejemplo 10: ",ejemplo10(h))
  print("Ejemplo 11: ",ejemplo11(h))
  print("Ejemplo 12: ",ejemplo12(h))
  print("Ejemplo 13: ",ejemplo13(h))
  print("Ejemplo 14: ",ejemplo14(h))
  print("Ejemplo 15: ",ejemplo15(h))
  vuelta += 1
main()
# Out:
# Tiempo transcurrido: 0.0000362396 segundos.
# Ejemplo 2:  729
# Tiempo transcurrido: 0.0000061989 segundos.
# Ejemplo 3:  27
# Tiempo transcurrido: 0.0000011921 segundos.
# Ejemplo 4:  54.849599999999995
# Tiempo transcurrido: 0.0000038147 segundos.
# Ejemplo 5:  361
# Tiempo transcurrido: 0.0027232170 segundos.
# Ejemplo 6:  19683
# Tiempo transcurrido: 0.0009620190 segundos.
# Ejemplo 7:  18225
# Tiempo transcurrido: 0.0018754005 segundos.
# Ejemplo 7_2:  36450
# Tiempo transcurrido: 0.0000021458 segundos.
# Ejemplo 8:  6
# Tiempo transcurrido: 0.0000050068 segundos.
# Ejemplo 9:  54
# Tiempo transcurrido: 0.0000379086 segundos.
# Ejemplo 10:  378
# Ejemplo 11:  4
# Tiempo transcurrido: 0.0000169277 segundos.
# Ejemplo 12:  78
# n = 27
# Ejemplo 13:  1
# Ejemplo 14:  6
# Ejemplo 15:  734
