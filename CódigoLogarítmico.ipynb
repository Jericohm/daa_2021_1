# %% [markdown]
# <a href="https://colab.research.google.com/github/Jericohm/daa_2021_1/blob/master/C%C3%B3digoLogar%C3%ADtmico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ejemplo4 (n):
  count = 0
  i = n
  print("Nivel 1")
  while i >= 1:
    print("Nivel 2")
    count +=1
    i = i // 2
  basura = 3 + 2
  return count

def main():
  f = 10
  while f <= 1000000000: """Hasta 1 Billón"""
    print(ejemplo4(f))
    f = f * 10
main()
# Out:
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# 4
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# 7
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# 10
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# 14
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# 17
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# 20
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# ...
